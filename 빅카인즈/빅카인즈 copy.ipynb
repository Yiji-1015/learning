# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForSequenceClassification
import torch.nn.functional as F
from langchain_upstage import ChatUpstage
from langchain_core.messages import HumanMessage, SystemMessage

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### 뉴스 감성분석

# %%
tokenizer = AutoTokenizer.from_pretrained("snunlp/KR-FinBert-SC")
model = AutoModelForSequenceClassification.from_pretrained("snunlp/KR-FinBert-SC")

def predict_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="longest", max_length=512)
    logits = model(**inputs).logits
    probs = F.softmax(logits, dim=-1)
    sentiment = "positive" if probs[0, 1] > 0.5 else "negative"
    return sentiment, probs.detach().tolist()

# 모델이 분류한 긍정/중립/부정 각각에 대해 얼마나 자신 있는지를 수치로 나타낸 것

# %%
predict_sentiment("""
역대 최저 출산율 속에서도 국내 키즈용품 시장이 오히려 성장하고 있다. 출산율은 줄었지만, 한 아이에게 지갑을 여는 가족 구성원은 많아졌기 때문이다. 부모는 물론 조부모, 삼촌, 이모 등 최대 10명에 이르는 친인척이 한 아이에게 집중적으로 소비하며 ‘VIB(Very Important Baby)’ 트렌드가 확산되고 있다.
통계청이 발표한 2025년 4월 인구동향에 따르면, 해당 월 출생아 수는 2만717명으로 전년 동월보다 1658명(8.7%) 증가했다. 이는 2022년 4월 이후 처음으로 2만 명대를 회복한 수치이며, 4월 기준 출생률 증가율로는 1991년 이후 34년 만에 최고치다. 이러한 추세가 이어질 경우, 올해 합계출산율이 0.8명을 넘어설 가능성도 제기되고 있다.
# ‘골드키즈’ 겨냥한 키즈 브랜드 고성장
라이프스타일 플랫폼 29CM(이십구센티미터)는 최근 약 3개월간(4월 1일~7월 17일) ‘29선물하기’ 서비스 데이터를 분석한 결과, 키즈 카테고리 거래액이 전년 동기간 대비 5배 이상 증가한 것으로 나타났다. 주요 고객층인 2539세대 여성들이 조카나 지인의 자녀를 위한 선물 수요를 주도하며, 감각적인 디자인의 키즈 브랜드에 대한 관심이 높아지고 있다.
실제로 여름 시즌을 맞아 수영복과 모자는 인기 선물 아이템으로 부상했다. 영유아 의류 브랜드 ‘콘크리트브레드’의 소스레시피 수영복과 스윔보넷은 원색 컬러와 귀여운 그래픽 디자인으로 주목받으며 키즈 선물 카테고리 1위를 차지했다. 영유아 패브릭 브랜드 ‘모노레임’의 바디슈트와 애착 인형 역시 출산 선물로 큰 인기를 끌고 있다. 특히 바디슈트는 오가닉 순면 소재와 민들레 일러스트 패턴, 선물용 패키지 구성이 돋보인다. 애착 인형은 편안함을 느끼도록 납작한 수건 형태로 제작돼 실용성을 더했다.
29CM는 고객의 취향을 반영해 ‘베베노피노’, ‘세아랑’, ‘콘크리트브레드’, ‘모노레임’ 등 독창적인 디자인을 갖춘 키즈 브랜드 큐레이션을 강화하고 있으며, 다양한 가족의 이야기를 담은 오리지널 콘텐츠 ‘29 I, Like’를 통해 브랜드 접점을 확대하고 있다.
29CM는 최근 약 3개월간(4월 1일~7월 17일) ‘29선물하기’ 서비스 데이터를 분석한 결과, 키즈 카테고리 거래액이 전년 동기간 대비 5배 이상 증가한 것으로 나타났다.
신세계백화점 역시 키즈 시장 공략에 나섰다. 올해 2월부터 마크곤잘레스 키즈, 마리떼 키즈, LEE 키즈, 커버낫 키즈 등 성인 스트리트 감성을 반영한 키즈 브랜드를 대거 도입해 정식 입점까지 이끌었다. 기존의 귀엽고 아기자기한 이미지에서 벗어나 성인 패션 트렌드를 키즈에 접목하며 아동복의 눈높이를 한층 높였다.
그 결과, 신세계백화점의 아동복 부문은 2월부터 6월까지 전년 동기 대비 27% 이상 매출 상승을 기록했다. 트렌디한 브랜드 라인업이 패션에 민감한 2030 부모층의 소비욕을 자극한 것이 주요 배경으로 분석된다.
‘골드키즈’를 위한 소비 트렌드는 건강기능식품 시장으로도 확장되고 있다. 한국건강기능식품협회에 따르면, 2023년 국내 키즈 건강기능식품 시장은 약 2599억 원 규모로, 2020년 대비 52% 성장했다. 최근에는 식약처로부터 어린이 키 성장 기능성을 인정받은 유산균발효굴추출물(FGO) 성분이 각광받고 있다.
정관장은 이를 바탕으로 출시한 ‘아이키커 하이’ 제품으로 히트를 기록했다. 이 제품은 출시 첫날 5억 원 이상의 매출을 올리며 주목받았으며, 주요 구매층은 40대 학부모로 집계됐다. 자녀의 성장 골든타임에 맞춰 24주분 구성이 전체 판매량의 74%를 차지하며 여름방학 수요와 맞물려 큰 인기를 끌고 있다.
골드키즈 트렌드는 국내뿐만 아니라 해외에서도 나타나고 있다.
국내 유아 브랜드 궁중비책은 지난 7월 16일부터 18일까지 중국 상하이에서 열린 ‘제25회 CBME 2025’ 박람회에 참가해 현지 바이어들의 큰 호응을 얻었다. CBME는 세계 3대 유아용품 박람회로, 4,500여 개 브랜드와 약 10만 명의 업계 관계자가 참가하는 글로벌 행사다.
궁중비책은 이 자리에서 국내 아동용 자외선 차단제 최초로 중국 국가약품감독관리국(NMPA) 등록을 마친 선케어 라인을 포함해, 키즈·베이비 라인을 선보였다. 특히 인기 캐릭터 ‘가필드’와의 협업, 한국적인 전통 미감을 살린 부스 디자인, 현지 KOL 초청 라이브 방송 등 전략적 마케팅이 주목받았다.
전시 기간 동안 궁중비책 부스는 약 3000명의 관람객이 방문했고, 현재는 티몰, 징동, 월마트, 샘스클럽 등 온·오프라인 유통 채널을 통해 중국 내 입지를 넓히고 있다.
# “하나뿐인 아이에게 프리미엄을”… 키즈 시장 고급화 전략
출산율 하락에도 불구하고 키즈 시장은 ‘질적 성장’으로 활로를 찾고 있다. ‘한 명뿐인 아이에게는 아낌없이 투자한다’는 골드키즈 소비 트렌드는 디자인과 기능성, 정체성을 겸비한 키즈 브랜드의 성장 원동력이 되고 있다.
유통가와 브랜드들은 이러한 흐름을 반영해 프리미엄화, 큐레이션, 글로벌 진출 등으로 키즈 시장의 새로운 가능성을 열고 있다.
업계 관계자는 “과거에는 키즈 브랜드가 기능성과 가격 경쟁력에 초점을 맞췄다면, 지금은 디자인, 브랜드 정체성, 큐레이션 서비스가 핵심 경쟁력으로 떠올랐다”며 “특히 Z세대 부모와 이모·삼촌 소비자층의 유입은 키즈 시장을 트렌디하고 감성적인 영역으로 이끌고 있으며, 이는 향후 세분화된 프리미엄 시장 확대로 이어질 것”이라고 말했다.""")
# Out:
# ('positive',
#  [[4.993687616661191e-05, 0.9999046325683594, 4.5448010496329516e-05]])

# %% [markdown]
# ### 뉴스 요약

# %%
tokenizer = AutoTokenizer.from_pretrained("psyche/KoT5-summarization")
model = AutoModelForSeq2SeqLM.from_pretrained("psyche/KoT5-summarization")

prefix = "summarize: "
sample = """
역대 최저 출산율 속에서도 국내 키즈용품 시장이 오히려 성장하고 있다. 출산율은 줄었지만, 한 아이에게 지갑을 여는 가족 구성원은 많아졌기 때문이다. 부모는 물론 조부모, 삼촌, 이모 등 최대 10명에 이르는 친인척이 한 아이에게 집중적으로 소비하며 ‘VIB(Very Important Baby)’ 트렌드가 확산되고 있다.
통계청이 발표한 2025년 4월 인구동향에 따르면, 해당 월 출생아 수는 2만717명으로 전년 동월보다 1658명(8.7%) 증가했다. 이는 2022년 4월 이후 처음으로 2만 명대를 회복한 수치이며, 4월 기준 출생률 증가율로는 1991년 이후 34년 만에 최고치다. 이러한 추세가 이어질 경우, 올해 합계출산율이 0.8명을 넘어설 가능성도 제기되고 있다.
# ‘골드키즈’ 겨냥한 키즈 브랜드 고성장
라이프스타일 플랫폼 29CM(이십구센티미터)는 최근 약 3개월간(4월 1일~7월 17일) ‘29선물하기’ 서비스 데이터를 분석한 결과, 키즈 카테고리 거래액이 전년 동기간 대비 5배 이상 증가한 것으로 나타났다. 주요 고객층인 2539세대 여성들이 조카나 지인의 자녀를 위한 선물 수요를 주도하며, 감각적인 디자인의 키즈 브랜드에 대한 관심이 높아지고 있다.
실제로 여름 시즌을 맞아 수영복과 모자는 인기 선물 아이템으로 부상했다. 영유아 의류 브랜드 ‘콘크리트브레드’의 소스레시피 수영복과 스윔보넷은 원색 컬러와 귀여운 그래픽 디자인으로 주목받으며 키즈 선물 카테고리 1위를 차지했다. 영유아 패브릭 브랜드 ‘모노레임’의 바디슈트와 애착 인형 역시 출산 선물로 큰 인기를 끌고 있다. 특히 바디슈트는 오가닉 순면 소재와 민들레 일러스트 패턴, 선물용 패키지 구성이 돋보인다. 애착 인형은 편안함을 느끼도록 납작한 수건 형태로 제작돼 실용성을 더했다.
29CM는 고객의 취향을 반영해 ‘베베노피노’, ‘세아랑’, ‘콘크리트브레드’, ‘모노레임’ 등 독창적인 디자인을 갖춘 키즈 브랜드 큐레이션을 강화하고 있으며, 다양한 가족의 이야기를 담은 오리지널 콘텐츠 ‘29 I, Like’를 통해 브랜드 접점을 확대하고 있다.
29CM는 최근 약 3개월간(4월 1일~7월 17일) ‘29선물하기’ 서비스 데이터를 분석한 결과, 키즈 카테고리 거래액이 전년 동기간 대비 5배 이상 증가한 것으로 나타났다.
신세계백화점 역시 키즈 시장 공략에 나섰다. 올해 2월부터 마크곤잘레스 키즈, 마리떼 키즈, LEE 키즈, 커버낫 키즈 등 성인 스트리트 감성을 반영한 키즈 브랜드를 대거 도입해 정식 입점까지 이끌었다. 기존의 귀엽고 아기자기한 이미지에서 벗어나 성인 패션 트렌드를 키즈에 접목하며 아동복의 눈높이를 한층 높였다.
그 결과, 신세계백화점의 아동복 부문은 2월부터 6월까지 전년 동기 대비 27% 이상 매출 상승을 기록했다. 트렌디한 브랜드 라인업이 패션에 민감한 2030 부모층의 소비욕을 자극한 것이 주요 배경으로 분석된다.
‘골드키즈’를 위한 소비 트렌드는 건강기능식품 시장으로도 확장되고 있다. 한국건강기능식품협회에 따르면, 2023년 국내 키즈 건강기능식품 시장은 약 2599억 원 규모로, 2020년 대비 52% 성장했다. 최근에는 식약처로부터 어린이 키 성장 기능성을 인정받은 유산균발효굴추출물(FGO) 성분이 각광받고 있다.
정관장은 이를 바탕으로 출시한 ‘아이키커 하이’ 제품으로 히트를 기록했다. 이 제품은 출시 첫날 5억 원 이상의 매출을 올리며 주목받았으며, 주요 구매층은 40대 학부모로 집계됐다. 자녀의 성장 골든타임에 맞춰 24주분 구성이 전체 판매량의 74%를 차지하며 여름방학 수요와 맞물려 큰 인기를 끌고 있다.
골드키즈 트렌드는 국내뿐만 아니라 해외에서도 나타나고 있다.
국내 유아 브랜드 궁중비책은 지난 7월 16일부터 18일까지 중국 상하이에서 열린 ‘제25회 CBME 2025’ 박람회에 참가해 현지 바이어들의 큰 호응을 얻었다. CBME는 세계 3대 유아용품 박람회로, 4,500여 개 브랜드와 약 10만 명의 업계 관계자가 참가하는 글로벌 행사다.
궁중비책은 이 자리에서 국내 아동용 자외선 차단제 최초로 중국 국가약품감독관리국(NMPA) 등록을 마친 선케어 라인을 포함해, 키즈·베이비 라인을 선보였다. 특히 인기 캐릭터 ‘가필드’와의 협업, 한국적인 전통 미감을 살린 부스 디자인, 현지 KOL 초청 라이브 방송 등 전략적 마케팅이 주목받았다.
전시 기간 동안 궁중비책 부스는 약 3000명의 관람객이 방문했고, 현재는 티몰, 징동, 월마트, 샘스클럽 등 온·오프라인 유통 채널을 통해 중국 내 입지를 넓히고 있다.
# “하나뿐인 아이에게 프리미엄을”… 키즈 시장 고급화 전략
출산율 하락에도 불구하고 키즈 시장은 ‘질적 성장’으로 활로를 찾고 있다. ‘한 명뿐인 아이에게는 아낌없이 투자한다’는 골드키즈 소비 트렌드는 디자인과 기능성, 정체성을 겸비한 키즈 브랜드의 성장 원동력이 되고 있다.
유통가와 브랜드들은 이러한 흐름을 반영해 프리미엄화, 큐레이션, 글로벌 진출 등으로 키즈 시장의 새로운 가능성을 열고 있다.
업계 관계자는 “과거에는 키즈 브랜드가 기능성과 가격 경쟁력에 초점을 맞췄다면, 지금은 디자인, 브랜드 정체성, 큐레이션 서비스가 핵심 경쟁력으로 떠올랐다”며 “특히 Z세대 부모와 이모·삼촌 소비자층의 유입은 키즈 시장을 트렌디하고 감성적인 영역으로 이끌고 있으며, 이는 향후 세분화된 프리미엄 시장 확대로 이어질 것”이라고 말했다."""

inputs = [prefix + sample]


inputs = tokenizer(inputs, max_length=512, truncation=True, return_tensors="pt")
output = model.generate(**inputs, num_beams=3, do_sample=True, min_length=100, max_length=500)
decoded_output = tokenizer.batch_decode(output, skip_special_tokens=True)
# result = nltk.sent_tokenize(decoded_output.strip())

decoded_output
# Out:
# ['역대 최저 출산율 속에서도 국내 키즈용품 시장이 오히려 성장하고 있는데, 주요 고객층인 2539세대 여성들이 조카나 지인의 자녀를 위한 선물 수요를 주도하며, 감각적인 디자인의 키즈 브랜드에 대한 관심이 높아지고 있고, 키즈 카테고리 거래액이 전년 동기간 대비 5배 이상 증가한 것으로 나타났다. 29CM는 고객의 취향을 반영해 베베노피노, 세아랑, 콘크리트브레드, 모노레임 등 독창적인 디자인을 갖춘 키즈 브랜드 큐레이션을 강화하고 있으며, 다양한 가족의 이야기를 담은 오리지널 콘텐츠 29 I, Like를 통해 브랜드 접점을 확대하고 있다.']

# %% [markdown]
# ### 가상 국민 판단 생성 (persona_agent)

# %%
news_list = ['인천시는 맞춤형 출산장려정책을 통해 출생아 수가 전년 동기 대비 12.3% 증가했다고 7월 통계청 발표를 인용해 밝혔다. 24일 시에 따르면 올해 1월부터 5월까지 인천시의 출생아 수는 총 6868명으로, 이는 전년 동기 대비 1278명이 늘어난 수치다. 인천시의 아이플러스(i+) 정책은 출산부터 양육까지 생애주기별 맞춤형 지원을 제공하며 출생률 상승에 기여하고 있다. 아이플러스(i+) 1억 드림은 인천에서 태어난 모든 아동에게 1억 원 상당의 지원을 제공하며, 교통비와 천사지원금, 아이꿈수당 등 다양한 혜택을 통해 시민들의 출산의욕을 고취하고 있다.',
             '경상북도와 대구경북인터넷기자협회는 24일 경북도청 다목적홀에서 저출생 극복, 일본 나기초 성공사례 세미나를 공동 개최하여 지방소멸 위기 속에서 출산율을 끌어올린 일본 오카야마현 나기초()의 정책을 공유하고, 지역 맞춤형 대응방안을 논의하는 자리로 마련했으며 오쿠 마사치카 나기초장은 인구감소는 마을의 기초를 흔드는 심각한 문제이며, 이를 극복하기 위해 젊은 세대가 안심하고 머물 수 있는 환경이 필요하다고 강조했다.',
             '주형환 저출산고령사회위원회 부위원장은 비수도권 거점 도시 육성을 위해 \'세컨드홈\'(두 번째 집) 세제 혜택을 확대할 필요가 있다고 22일 제안했다. 그는 특히 "균형발전특별회계가 20년째 운영 중이고 투입된 금액도 190조원에 이르지만 수도권 집중은 악화일로"라며 "균형의 강박에서 벗어나 선택과 집중을 해야 할 때"라고 말했다. 이어 "소득수준과 산업기반, 정주 여건 등이 고르게 잘 돼 있는 권역을 중심으로 거점도시를 집중적으로 육성해야 한다"면서 "수도권 1주택 보유자가 세컨드홈을 구입해도 1주택자로 인정하는 세제 혜택을 지방 대도시에도 적용하고 수도권 주택을 매각하고 내려가는 경우 양도소득세를 면제하는 방식을 검토하자"고 제안했다.',
             '베트남 정부가 급격한 저출산과 성비 불균형 문제에 대응하기 위해 \'딸 자녀 가정 대상 현금 지원\'을 포함한 새로운 인구정책을 준비 중이다. 13일(현지시각) 베트남 매체 VN익스프레스에 따르면 다오 홍 란 베트남 보건부 장관은 지난 11일 하노이에서 열린 세계 인구의 날 기념식에서 "지역과 국가 차원의 인구 문제에 적극 대응하기 위해 새로운 정책 마련에 착수했다"라고 밝혔다. 베트남 보건부가 마련 중인 주요 대책으로는 출산 및 양육 장려금 산전·후 건강검진 지원 유자녀 가정 대상의 주거 보조 딸만 있는 가정을 위한 현금 또는 물질적 인센티브 제공 등이 포함된 것으로 알려졌다.',
             '2025년 들어 대구의 출생아 수가 전국 평균을 크게 웃도는 수준으로 뚜렷한 증가세를 보이며 출생 반등 흐름을 주도하고 있지만, 경북은 여전히 미미한 증가에 그치며 지역 간 온도차가 뚜렷하게 나타나고 있다. 혼인은 줄고 출산은 늘어나는 흐름은 전통적인 인구 구조 공식에서 벗어난 모습이다. 특히 대구는 결혼 감소에도 출산이 증가한 대표적인 지역으로, 전문가들은 혼인과 출산의 연계성이 점차 약해지는 사회 구조 변화가 통계로 나타난 것이라고 분석하고 있다.',
             "저출산고령사회위원회(저출산위)는 임신·육아 종합 포털인 '아이사랑' 누리집에 상생형 직장어린이집 검색 및 입소 신청 기능을 추가한다고 23일 밝혔으며 상생형 직장어린이집은 중소기업이 공동으로 운영하거나, 국가기관 혹은 지방자치단체·대기업 등이 협력사 및 인근 중소기업 직원과 지역 주민에게 개방하는 보육시설이다. 그러나 상생형 직장어린이집에 대한 정보가 부족해 지역 주민이 이용하지 못하거나 입소 절차에 어려움을 겪는 경우가 많다는 현장의 지적에 따라 아이사랑 포털에 관련 정보를 추가하는 방식으로 개편하기로 했다.",
             '현대건설이 초저출산 문제가 국가적 위기로 떠오른 가운데 임직원의 일과 가정의 양립을 위한 제도로 출산장려금, 배우자 출산휴가, 육아휴직, 유연근무제 등을 운영하는 등 전방위 제도를 도입하며 기업 차원의 대응에 나섰으며, 관계자는 임직원이 개인의 삶과 업무를 조화롭게 영위할 수 있도록 다양한 제도적 기반을 마련하고 있다"고 말했다. 현대다솜어린이집을 운영 중이며, 본사에는 임산부를 위한 수유실과 전용 주차구역도 마련돼 있다.',
             "저출산고령사회위원회와 보건복지부는 제14차 인구비상대책회의를 개최하고 '2025년 저출산·고령사회 시행 계획'을 심의·확정했다고 4일 밝혔다. 이번 시행 계획은 저출산고령사회기본법 23조에 따라 수립하는 '제4차 저출산·고령사회 기본계획'(2020~2025년) 마지막 연도 계획으로 중앙정부와 지자체는 매년 기본계획에 따른 시행 계획을 수립해 추진해 오고 있다. 2025년 저출산·고령사회 시행 계획은 '제4차 기본계획'을 기반으로 '저출생 추세반전 대책' 등 지난해 발표한 주요 정책들을 반영해 과제별로 세부적 추진 방안을 담았다.",
             "2013년 처음 방송된 이래 12년간 국민의 사랑을 받고 있는 '슈퍼맨이 돌아왔다'(연출 김영민, 이하 '슈돌')는 추성훈과 추사랑, 송일국과 삼둥이를 비롯해 이동국과 오남매, 샘 해밍턴과 윌벤 형제, 사유리와 젠, 김준호와 은우-정우 형제, 제이쓴과 준범 등 육아에 익숙하지 않은 부모가 아이를 통해 행복을 알게 되고, 다양한 가족의 형태를 새롭게 조명하며 육아의 값진 의미를 빛내고 있는 국내 유일의 육아 프로그램이다. 이런 가운데, 지난 11일 오후 서울 서초구 JW 메리어트 서울에서 열린 '제14회 인구의 날' 기념식에서 '슈돌'이 대통령 표창을 받으며 다시 한 번 '국민 육아 예능'다운 위엄을 드러냈다.",
             '역대 최저 출산율 속에서도 국내 키즈용품 시장이 오히려 성장하고 있는 가운데, 주요 고객층인 2539세대 여성들이 조카나 지인의 자녀를 위한 선물 수요를 주도하며, 감각적인 디자인의 키즈 브랜드에 대한 관심이 높아지고 있으며 실제로 여름 시즌을 맞아 수영복과 모자는 인기 선물 아이템으로 부상했다. 29CM(이십구센티미터)는 최근 약 3개월간(4월 1일~7월 17일) 29선물하기 서비스 데이터를 분석한 결과, 키즈 카테고리 거래액이 전년 동기간 대비 5배 이상 증가한 것으로 나타났다.']

# %%
policy = """
현재 시행되는 저출생 정책은 다음과 같습니다:
□ 양육 비용지원이 늘어납니다!
- 부모급여가 0세 월 100만원, 1세 월 50만원씩 지급됩니다.
- 첫만남 이용권이 첫째 200만원, 둘째 이상 300만원 지급됩니다.
□ 돌봄과 교육을 확대합니다!
- 늘봄학교가 모든 초등학교로 전면 확대됩니다.
□ 가족친화적 주거 서비스가 시행됩니다!
- 신혼부부의 주택구입·전세자금 대출 소득요건이 완화됩니다.(’23.10~)
* 주택 구입자금 대출의 경우 소득요건이 7000만 원에서 8500만 원 이하로, 전세자금 대출의 경우 소득요건이 6000만 원에서 7500만 원 이하로 완화됩니다.
- 청년 주택드림 청약통장이 신설되고 이자율은 4.3→4.5%로, 납입한도도 월 50→100만원으로 확대됩니다.(’24.2)
* 청약 당첨 시, 분양가 80%까지 저리·장기 자금 지원이 가능하며, 결혼·최초 출산 시 우대금리를 추가 지원합니다!
- 신생아 출산가구의 주택구입·전세대출 특례가 신설됩니다.
□ 일·가정 양립을 위한 지원제도가 확대됩니다.
- 6+6 부모육아휴직 시 통상임금의 100%(월 최대 450만원까지)가 지급됩니다.
* 생후 18개월 내 자녀를 둔 부모 모두가 육아휴직 사용 시, 첫 6개월에 대해 부모 각각의 육아휴직 급여를 통상임금의 100% 지원합니다. (월 최대 450만원)
- 육아기 근로자 시차출퇴근 장려금(월 20만원)이 신설됩니다.
- 아이돌보미 이용가구를 11만 가구까지 확대하고 2자녀 이상 정부지원을 대폭 확대합니다.
□ 건강한 아이, 행복한 부모를 위해! 다양한 지원제도가 시행됩니다.
- 난임 시술비 지원의 소득기준을 폐지하고, 냉동난자 보조생식술을 지원합니다.
- 고위험 임산부의 의료비 지원시 소득기준을 폐지합니다.
- 생후 24개월 미만 아동의 입원 진료시 본인부담률이 제로(0)가 됩니다.
- 미숙아·선천성 이상아 등 의료비 지원의 소득기준 폐지되며 지원 기간은 2년까지 확대합니다."""

# https://www.betterfuture.go.kr/front/policySpace/policyReferenceDetail.do?articleId=23&listLen=10&position=M

# %%
chat = ChatUpstage(model="solar-pro2-250710", temperature=0.7)

def get_messages(penal_info, x):
    return [
        SystemMessage(content=f"""
            당신은 패널의 생각을 묻는 역할을 맡은 AI입니다.
            parameter는 패널의 정보와 현재 시행 정책, 그리고 관련 뉴스 데이터입니다.
            당신의 목표는 사용자의 질문(input)에 대해 패널의 의견을 작성하는 것입니다.

            - 다음과 같은 **Chain-of-Thought(CoT)** 구조를 따라야 합니다. 다만 이를 직접적으로 언급하지 마세요.:
            1) 패널의 특성에 따른 그의 과거 판단 또는 가치 → 2) 최근 뉴스나 사회 변화에 대한 반응 → 3) 현재 판단 또는 민감한 이슈
            - 각 패널의 개인정보와 사회 뉴스 데이터를 반영해야 합니다. 각 패널의 특성에 따라 더 관심이 가는 뉴스 이슈가 있을 수 있으며, 이를 취합 후 반영하여 인터뷰 내용을 작성하세요.
            - 각 패널이 현재 정책에 대해 어떻게 생각할지 고려하여, 
            - 사족 없이, 오로지 패널 자신이 말하는 것처럼 답변하세요.
            - 하나의 문단으로 출력해야 하며, 반드시 1000자 이상의 긴 서술이 되어야 합니다.
        1. 패널 정보: {penal_info}
        2. 현재 시행 정책: {policy}
        3. 관련 뉴스 데이터: {news_list}
            """),
        HumanMessage(content=x)
    ]

# %%
question = "사용자의 질문: 부모급여를 50만원씩 상향하는 것에 대해 어떻게 생각하시나요? 이 정책이 저출생 문제 해결에 도움이 될까요?"

# %%
panel1 = {
    "ID": 1,
    "name": "최성호",
    "gender": "남",
    "region": "경기도",
    "age": "60~64세",
    "married": "사별",
    "income": "4분위",
    "education": "대학교-졸업"
}

response1 = chat.invoke(get_messages(panel1, question))
print(response1.content)
# Out:
# 현재 부모급여 상향안은 0세 100만 원, 1세 50만 원의 지원금을 각각 150만 원과 100만 원으로 확대하는 방안을 의미합니다. 60대 중반의 사별 남성으로서, 경기도에서 4분위 소득으로 생활하며 대학 교육을 받은 제 경험을 토대로 볼 때, 이 정책은 단기적 양육 부담 완화에는 일정 부분 기여할 수 있으나 근본적인 저출생 문제 해결에는 한계가 있다고 판단합니다.
#
# 첫째, 교육 수준과 경제력을 갖춘 제 세대에서는 자녀 양육의 경제적 비용보다 **미래에 대한 불확실성**이 더 큰 장벽으로 작용합니다. 최근 대구에서 혼인 감소와 출산 증가가 동시에 나타나는 현상(관련 뉴스 5)은 전통적 가족 구조의 변화를 반영하며, 경제적 지원만으로는 청년 세대의 결혼·출산 기피 심리를 해결하기 어렵다는 점을 시사합니다. 인천시의 '아이플러스(i+)' 정책(관련 뉴스 1)처럼 1억 원 규모의 장기 지원과 맞춤형 복지 패키지가 병행되지 않는다면, 일회성 금전 지원은 효과성이 낮을 수 있습니다.
#
# 둘째, 주거 문제와 일·가정 양립 지원 미비가 더 큰 걸림돌입니다. 현대건설의 사례(관련 뉴스 7)에서 보듯, 직장 내 수유실 확충이나 유연근무제 같은 **실질적인 인프라 개선**이 동반되어야 합니다. 특히 60대 이상 세대는 자녀 독립 후 주택 문제가 완화되지만, 청년층은 신혼부부 주택 대출 요건 완화(관련 뉴스 2)만으로는 수도권 집값 부담을 해결하기 어렵습니다. 주형환 부위원장의 '세컨드홈 세제 혜택' 제안(관련 뉴스 3)처럼 지역 간 균형 발전 전략이 병행되어야 출산 장려 효과가 나타날 것입니다.
#
# 셋째, 고령 사회의 특성상 **세대 간 가치관 차이**를 고려해야 합니다. 베트남의 '딸 자녀 가정 현금 지원'(관련 뉴스 4)이나 일본 나기초의 청년 정주 환경 조성(관련 뉴스 2)은 단순한 금전 지원보다 지역 사회 통합에 초점을 맞춘 사례입니다. 국내에서도 상생형 직장어린이집 정보 공개(관련 뉴스 6)처럼 육아 인프라를 가시화하는 정책이 더 시급합니다.
#
# ...

# %%
panel2 = {
    "ID": 2,
    "name": "이진호",
    "gender": "남",
    "region": "광주광역시",
    "age": "30~34세",
    "married": "배우자 있음",
    "income": "1분위",
    "education": "전문대-졸업"
}

response2 = chat.invoke(get_messages(panel2, question))
print(response2.content)
# Out:
# 저출생 대응 정책의 핵심은 경제적 부담 완화보다는 삶의 질 개선에 있다고 봐야 합니다. 광주에서 전문대를 졸업하고 지역 중소기업에 다니는 제 입장에서, 부모급여 50만원 상향은 당장의 생계비 절감에는 도움이 되겠지만 근본적인 해결책이 될 수 없습니다. 현재 1분위 소득층의 경우 월 100만원 지원금이라도 월세·전세대출 이자, 사교육비, 의료비 등 고정 지출을 감당하기 어렵습니다. 인천시의 '아이플러스 1억 드림'처럼 장기적 지원 체계가 부재한 한시적 현금 지원은 출산을 고민 중인 젊은 부부에게 확신을 주기 어렵습니다.
#
# 최근 경북 나기초 사례에서 보듯, 출산 인센티브보다 중요한 것은 청년층이 안정적으로 정착할 수 있는 주거·일자리 환경입니다. 제 경우에도 신혼부부 대출 요건 완화가 실제 주택 구매로 이어지지 않는 건 지역 내 양질의 일자리가 부족하기 때문입니다. 대구에서 혼인 감소와 출산 증가가 동시에 발생한 것은 결혼 없이도 양육이 가능한 사회적 인프라(공동육아나눔터, 24시간 어린이집 등)가 확대됐기 때문으로 분석됩니다.
#
# 정부 정책이 육아휴직 급여 100% 지원이나 시차출퇴근제와 같은 일·가정 양립 제도에 더 집중해야 한다고 생각합니다. 현대건설 사례처럼 직장 내 수유실 확충, 유연근무제 도입이 실제 출산율 상승으로 연결된 사례가 있습니다. 단기 현금 지원보다는 '육아 친화적 사회 시스템' 구축이 선행되어야 합니다. 특히 1분위 소득층을 위해 늘봄학교 확대 시 방과 후 교육비를 무료로 전환하거나, 미숙아 의료비 지원 기간을 2년에서 5년으로 연장하는 등 장기적 안전망 강화가 필요합니다.
#
# ...

# %%
panel3 = {
    "ID": 3,
    "name": "김정숙",
    "gender": "여",
    "region": "세종특별자치시",
    "age": "35~39세",
    "married": "미혼",
    "income": "3분위",
    "education": "고등학교-졸업"
}

response3 = chat.invoke(get_messages(panel3, question))
print(response3.content)
# Out:
# 현재 저출생 정책의 부모급여 상향은 단기적 경제적 부담 완화에 일정 부분 기여할 수 있겠지만, 근본적인 문제 해결에는 한계가 있다고 봅니다. 세종시에 거주하는 30대 미혼 여성으로, 고등학교 졸업 후 중소기업을 다니며 3분위 소득을 유지하는 입장에서 이 정책을 바라보면, 첫째에게 50만원, 둘째부터 100만원 추가 지원은 출산 비용 절감 효과는 있지만, 양육의 장기적 부담을 덜어주기엔 미흡해 보입니다. 인천시의 아이플러스(i+) 정책처럼 1억 원 규모의 생애주기별 지원이나 대구에서 나타난 혼인 감소와 출산 증가의 괴리와 같은 사회 구조 변화를 고려할 때, 단순히 현금 지원 확대만으로는 출산 의욕을 끌어올리기 어렵습니다.
#
# 특히 교육·주거·일자리 문제가 해결되지 않은 상황에서 부모급여 인상은 일시적 효과에 그칠 우려가 큽니다. 경북과 대구의 출생률 격차에서 보듯, 지역별 인프라와 지원 체계 차이가 명확히 드러나는 만큼, 세종과 같은 신도시는 상대적으로 양육 환경이 나은 편이지만, 청년들의 주거 비용 부담(예: 청약통장 납입 한도 확대만으로는 전세난 해결 불가)이나 비정규직의 육아휴직 접근성 문제는 여전히 남아 있습니다. 또한 현대건설의 직장어린이집 사례처럼 기업 차원의 맞춤형 지원이 확대되어야 하는 부분도 있습니다.
#
# 따라서 부모급여 상향은 필수적이지만, 출산 후 안정적인 양육을 위한 인프라 확충(예: 늘봄학교 전면 확대 시 교사 수급 문제 해결), 주거 지원 강화(신혼부부 대출 요건 완화를 넘어 공공주택 공급 확대), 비정규직의 육아휴직 보장 등 종합적 접근이 필요합니다. 베트남의 딸 자녀 현금 지원 정책이나 일본의 나기초 사례에서도 알 수 있듯, 지역 특성에 맞는 맞춤형 지원과 사회적 인식 개선이 동반되어야 지속 가능한 성과를 낼 수 있을 것입니다.
#
# ...

# %%
panel4 = {
    "ID": 4,
    "name": "심숙자",
    "gender": "여",
    "region": "경상북도",
    "age": "25~29세",
    "married": "배우자 있음",
    "income": "5분위",
    "education": "대학원박사-졸업"
}

response4 = chat.invoke(get_messages(panel4, question))
print(response4.content)
# Out:
# 현재 시행 중인 부모급여 정책의 상향 조율은 표면적으로는 경제적 부담 완화에 기여할 수 있겠으나, 근본적인 저출생 문제 해결에는 한계가 있을 것으로 보입니다. 경북 지역에 거주하며 대학원 박사 학위를 가진 20대 후반 기혼 여성으로서, 육아 지원 정책의 단기적 효과를 넘어 사회 구조적 문제에 대한 고민이 선행되어야 한다고 생각합니다.
#
# 첫째, 경제적 지원 확대는 이미 고소득층인 저에게는 직접적인 효용성이 낮습니다. 5분위 소득 계층은 기본 양육비용을 자체 감당할 수 있으나, 중산층 이하 계층의 경우 지원금 인상이 실질적인 출산 유인으로 작용할 가능성도 있습니다. 그러나 인천시의 '아이플러스(i+)' 정책 사례처럼 1억 원 규모의 포괄적 지원이 아닌 단순 현금성 지원은 출산 결심을 흔들기에는 역부족일 수 있습니다. 특히 경북과 대구의 출생률 격차에서 드러나듯, 지역별 인프라 격차가 더 큰 변수이기 때문입니다.
#
# 둘째, 정책 설계 시 '양육 비용'보다 '삶의 질'에 초점을 맞춰야 합니다. 출산 장려금 인상보다는 주거·고용·교육 시스템의 동시 개선이 필요합니다. 현대건설의 사례처럼 기업 차원의 유연근무제 확대나 직장어린이집 확충이 더 실질적인 영향을 미칩니다. 현재 정책의 주택구입 대출 완화 조치는 신혼부부에게 유용하나, 청년 주택드림 청약통장의 이자율 인상(4.3→4.5%)은 물가 상승률을 고려할 때 미미한 수준입니다.
#
# 셋째, 사회적 인식 변화가 동반되지 않는 한 정책의 지속 가능성은 낮습니다. 베트남의 '딸 자녀 가정 현금 지원' 사례처럼 성비 불균형 해소를 위한 인센티브를 도입할 경우 역효과가 발생할 수 있듯, 출산 장려 정책은 성별 역할 고정관념을 재생산할 위험도 있습니다. 육아휴직 급여 100% 확대(6+6 제도)는 긍정적이지만, 남성의 육아휴직 사용률이 10% 미만인 현실을 고려할 때 실질적 실행 방안이 부재합니다.
#
# ...

# %% [markdown]
# ### 인터뷰 생성(interview_agent) - Legacy

# %%
def get_opinions(x):
    return [
        SystemMessage(content="""
            당신은 공공 여론조사 전문가입니다.
            당신의 목표는 다음과 같습니다.
 
            - 가상 패널을 대상으로, 시행정책에 대한 질적 설문조사를 진행합니다.
            - 설문 조사에는 가상 패널의 특성과 더불어, 해당 패널의 사전 의견을 참고하십시오.
            - 전체 인터뷰는 1000자 내외입니다.
            """),
        HumanMessage(content=x)
    ]

# %%
prompt2 = f"""
    패널 정보: {panel1}
    사전 의견: {response1}
    시행정책:
1. 의결주문
  저출산ㆍ고령사회기본법 시행령 일부개정령안을 별지와 같이 의결한다.
2. 제안이유 및 주요내용
  아동 양육에 따른 경제적 부담을 경감하기 위해 출생아동에게 지급하는 첫만남이용권 지급 금액을 200만원 이상으로 상향하는 내용으로 「저출산ㆍ고령사회기본법」이 개정된 것에 맞추어, 첫째 출생아동에게는 200만원, 둘째 이후의 출생아동에게는 300만원의 첫만남이용권을 각각 지급하도록 하고, 해당 첫만남이용권의 사용 기한을 아동이 출생한 날부터 ‘1년이 되는 날’에서 ‘2년이 되는 날’까지로 연장하는 한편,
  저출산ㆍ고령사회위원회의 안정적 업무 수행을 위해 해당 위원회의 부위원장직을 상근직으로 전환하고, 저출산ㆍ고령사회 정책에 대한 효율적 법제 지원을 위해 법제처장을 당연직위원에 추가하는 등 현행 제도의 운영상 나타난 일부 미비점을 개선ㆍ보완하려는 것임.
    """

response = chat.invoke(get_opinions(prompt2))
print(response.content)
# Out:
# ### 최성호 패널 가상 인터뷰: 첫만남이용권 개정안에 대한 질적 의견
#
# **Q1. 기존 인천시 출산장려정책에서 생애주기별 지원의 중요성을 언급하셨습니다. 이번 개정안의 '첫만남이용권 금액 상향 및 사용 기한 연장'이 실제 출산 의지에 어떤 영향을 줄 것이라고 보시나요?**
# - "금액 상향은 긍정적이지만, 단순한 현금 지원보다는 **단계별 맞춤형 지원**이 더 효과적일 수 있습니다. 예를 들어, 첫째 200만원, 둘째 300만원은 차등을 뒀지만, 육아용품 구매보다는 **장기적 부담 완화를 위한 교육/주거 지원**과 연계되어야 지속 가능한 정책이 될 것 같습니다. 사용 기한 1년 연장은 신생아의 성장 단계를 고려한 현실적인 조치로 평가합니다."
#
# **Q2. 대구·경북 지역 간 편차 해소를 위해 거점 도시 육성을 제안하셨습니다. 이번 개정안의 상근 부위원장 제도 도입이 지역 간 정책 격차 감소에 기여할 수 있을까요?**
# - "위원회 운영의 안정성은 중요하지만, **지역별 특성을 반영한 실행 계획**이 수반되어야 합니다. 예를 들어, 경기도와 경북의 출산 장애 요인(예: 일자리 부족, 의료 접근성)은 다르므로, 상근 부위원장이 지역 현장 의견을 수렴해 **분권형 정책**을 추진할 수 있는 권한이 필요합니다. 단순히 중앙 위원회만 강화해서는 지역 간 편차를 해결하기 어렵습니다."
#
# **Q3. 기업 육아 지원 제도의 중요성을 강조하셨는데, 이번 개정안이 기업 참여를 유도하는 데 충분한가요?**
# - "현행 개정안은 기업에 대한 인센티브가 부재합니다. 세제 혜택이나 **중소기업 맞춤형 지원**을 확대하지 않으면, 기업의 자발적 참여는 제한적일 수 있습니다. 예를 들어, 육아휴직 활용률이 높은 기업에 세제 감면이나 공공조달 가점을 부여하는 방안이 병행되어야 합니다."
#
# **Q4. 사별 가정의 경우 출산·육아 정책에서 어떤 추가 고려가 필요하다고 생각하시나요?**
# ...

# %%
prompt2 = f"""
    패널 정보: {panel2}
    사전 의견: {response2}
    시행정책:
1. 의결주문
  저출산ㆍ고령사회기본법 시행령 일부개정령안을 별지와 같이 의결한다.
2. 제안이유 및 주요내용
  아동 양육에 따른 경제적 부담을 경감하기 위해 출생아동에게 지급하는 첫만남이용권 지급 금액을 200만원 이상으로 상향하는 내용으로 「저출산ㆍ고령사회기본법」이 개정된 것에 맞추어, 첫째 출생아동에게는 200만원, 둘째 이후의 출생아동에게는 300만원의 첫만남이용권을 각각 지급하도록 하고, 해당 첫만남이용권의 사용 기한을 아동이 출생한 날부터 ‘1년이 되는 날’에서 ‘2년이 되는 날’까지로 연장하는 한편,
  저출산ㆍ고령사회위원회의 안정적 업무 수행을 위해 해당 위원회의 부위원장직을 상근직으로 전환하고, 저출산ㆍ고령사회 정책에 대한 효율적 법제 지원을 위해 법제처장을 당연직위원에 추가하는 등 현행 제도의 운영상 나타난 일부 미비점을 개선ㆍ보완하려는 것임.
    """

response = chat.invoke(get_opinions(prompt2))
print(response.content)
# Out:
# ### 인터뷰 질문 및 가상 패널 이진호 씨의 답변 (1,000자 내외)
#
# #### 1. **정책 인지도 및 기본 평가**
# **Q.** 이번에 첫만남이용권 금액이 상향되고 사용 기한이 2년으로 연장되는 정책을 알고 계셨나요? 이 변화에 대한 첫인상은 어떠신가요?
# **A.** (사전 의견 반영)
# "뉴스에서 관련 정책을 접했습니다. 금액 인상과 기한 연장은 긍정적이지만, 광주 저소득층의 경우 단기적 현금 지원만으로는 출산 결정에 대한 근본적인 고민이 해결되지 않을 것 같습니다. 예를 들어, 200~300만원은 출산 비용(의료비, 육아용품)에 일부 도움이 되겠지만, 안정적인 주거 비용이나 중장기적인 교육비와 비교하면 여전히 부족할 수 있습니다. 특히 중소기업에 다니는 경우 직장 내 육아 지원 인프라가 부족해 실질적 효과를 의문시하게 됩니다."
#
# #### 2. **경제적 부담 완화 필요성**
# **Q.** 사전 의견에서 "경제적 기반 강화(고용·주거 안정)"를 강조하셨습니다. 이번 정책이 해당 부분을 보완한다고 보시나요?
# **A.**
# "정책은 현금 지원에 집중되어 있습니다. 광주 지역의 저소득 가구는 월급의 30% 이상을 주거비로 지출하는 경우가 많아, 일회성 지원금만으로는 생활 안정성을 확보하기 어렵습니다. 예를 들어, 전세자금 대출 지원이나 공공주택 확대와 같은 정책과 병행되지 않으면, 출산 후 경제적 스트레스가 다시 발생할 수 있습니다. 또한, 청년 일자리 부족으로 인해 출산을 미루는 사례도 많아 고용 정책과의 연계가 필수적입니다."
#
# #### 3. **사용 기한 연장에 대한 실용성**
# **Q.** 첫만남이용권 사용 기한이 1년에서 2년으로 연장된 점은 육아 비용 분산에 도움이 될 것으로 보입니다. 실제로 유용하다고 생각하시나요?
# **A.**
# ...

# %%
prompt2 = f"""
    패널 정보: {panel3}
    사전 의견: {response3}
    시행정책:
1. 의결주문
  저출산ㆍ고령사회기본법 시행령 일부개정령안을 별지와 같이 의결한다.
2. 제안이유 및 주요내용
  아동 양육에 따른 경제적 부담을 경감하기 위해 출생아동에게 지급하는 첫만남이용권 지급 금액을 200만원 이상으로 상향하는 내용으로 「저출산ㆍ고령사회기본법」이 개정된 것에 맞추어, 첫째 출생아동에게는 200만원, 둘째 이후의 출생아동에게는 300만원의 첫만남이용권을 각각 지급하도록 하고, 해당 첫만남이용권의 사용 기한을 아동이 출생한 날부터 ‘1년이 되는 날’에서 ‘2년이 되는 날’까지로 연장하는 한편,
  저출산ㆍ고령사회위원회의 안정적 업무 수행을 위해 해당 위원회의 부위원장직을 상근직으로 전환하고, 저출산ㆍ고령사회 정책에 대한 효율적 법제 지원을 위해 법제처장을 당연직위원에 추가하는 등 현행 제도의 운영상 나타난 일부 미비점을 개선ㆍ보완하려는 것임.
    """

response = chat.invoke(get_opinions(prompt2))
print(response.content)
# Out:
# **김정숙 패널 인터뷰: 첫만남이용권 상향 및 세종시 출산정책 방향에 대한 의견**
#
# **Q1. 정책 개요 설명**
# "안녕하세요, 김정숙 님. 이번 개정안은 첫째아 200만원, 둘째아 300만원의 첫만남이용권을 지급하고 사용 기한을 2년으로 연장한 내용입니다. 또한 저출산위원회 운영 효율화를 위한 조직 개편도 포함되었습니다. 이 정책에 대한 첫인상을 어떻게 보시나요?"
#
# **A1. 긍정적 평가**
# "출생율 제고를 위한 경제적 지원 확대는 기본적으로 긍정적입니다. 특히 사용 기한 연장은 육아용품 구매뿐 아니라 교육·의료 비용에도 유연하게 대응할 수 있어 실용성이 높아졌어요. 다만, 세종시 청년층에게는 주거 문제 해결이 더 시급하다는 생각은 여전합니다."
#
# **Q2. 지역 맞춤형 지원 필요성**
# "사전 의견에서 세종시의 청년 정착 지원 강조를 언급하셨는데, 이번 정책이 지역 특성과 어떻게 연계되어야 한다고 보시나요?"
#
# **A2. 주거·육아 인프라 병행 필요**
# "첫만남이용권만으로는 부족합니다. 세종시는 청년 공무원·신혼부부가 많지만, 전세난과 직장어린이집 접근성 문제가 심각해요. 예를 들어, 이용권 지급과 연계해 청년 전용 주택 할당제나 기업-지자체 협력형 육아시설 확충이 필요하다고 봅니다."
#
# **Q3. 기업 참여 확대 방안**
# "기업 차원의 육아 지원 확대를 주장하셨는데, 이번 정책이 민간 부문의 참여를 촉진할 수 있을까요?"
#
# **A3. 인센티브 시스템 제안**
# "이용권 지급만으로는 기업의 자발적 참여를 유도하기 어렵습니다. 세제 혜택이나 인증제도와 연계해 직장어린이집 설치 기업에 가산점을 주는 등 인센티브가 필요해요. 특히 세종시 내 공공기관과 중소기업이 협력하면 상생 모델을 만들 수 있을 겁니다."
#
# **Q4. 정책 개선 건의**
# "마지막으로, 이번 개정안의 효과를 높이기 위해 추가되어야 할 사항은 무엇이라고 생각하시는지요?"
#
# **A4. 정보 접근성 강화**
# ...

# %%
prompt2 = f"""
    패널 정보: {panel4}
    사전 의견: {response4}
    시행정책:
1. 의결주문
  저출산ㆍ고령사회기본법 시행령 일부개정령안을 별지와 같이 의결한다.
2. 제안이유 및 주요내용
  아동 양육에 따른 경제적 부담을 경감하기 위해 출생아동에게 지급하는 첫만남이용권 지급 금액을 200만원 이상으로 상향하는 내용으로 「저출산ㆍ고령사회기본법」이 개정된 것에 맞추어, 첫째 출생아동에게는 200만원, 둘째 이후의 출생아동에게는 300만원의 첫만남이용권을 각각 지급하도록 하고, 해당 첫만남이용권의 사용 기한을 아동이 출생한 날부터 ‘1년이 되는 날’에서 ‘2년이 되는 날’까지로 연장하는 한편,
  저출산ㆍ고령사회위원회의 안정적 업무 수행을 위해 해당 위원회의 부위원장직을 상근직으로 전환하고, 저출산ㆍ고령사회 정책에 대한 효율적 법제 지원을 위해 법제처장을 당연직위원에 추가하는 등 현행 제도의 운영상 나타난 일부 미비점을 개선ㆍ보완하려는 것임.
    """

response = chat.invoke(get_opinions(prompt2))
print(response.content)
# Out:
# ### 심숙자 패널 심층 인터뷰 (가상)
#
# **정책 개요 설명**:
# "심숙자 님, 이번에 개정된 첫만남이용권 정책은 첫째 200만원, 둘째 300만원을 지급하고 사용 기한을 1년에서 2년으로 연장한 것이 핵심입니다. 또한 저출산위원회 운영 효율화를 위해 부위원장을 상근직으로 전환하고 법제처장이 위원으로 참여하는 내용도 포함됐습니다. 이 정책에 대한 의견을 여쭤보고 싶습니다."
#
# **1. 경제적 지원 확대 효과**:
# - **심숙자**: "금액 인상과 사용 기한 연장은 긍정적이에요. 특히 2년으로 연장하면 육아용품 구매나 교육비 준비에 시간적 여유가 생깁니다. 다만, 비수도권 거주자에게는 추가 인센티브(예: 주거비 지원)가 필요할 것 같아요. 경북은 대구보다 인프라 격차가 크거든요."
# - **추가 질문**: "5분위 소득층으로서, 이 정책이 출산 의향에 영향을 미칠까요?"
# - **답변**: "개인적으론 경제적 부담 감소 효과가 있겠지만, 장기적으로는 직장 내 육아 지원(탄력근무제 확대 등)이 동반되어야 합니다. 현재의 세제 혜택은 고소득층에게 더 유리해 보입니다."
#
# **2. 지역 간 균형 발전 가능성**:
# - **심숙자**: "대구-경북 출생률 격차는 '혼인-출산 연계성 약화'에서 비롯된 것 같아요. 경북처럼 신혼부부가 정주할 수 있는 환경(주거·교통·일자리)을 조성하지 않으면, 단순한 현금 지원만으로는 한계가 있습니다. 일본 나기초 사례처럼 지역사회와 연계한 맞춤형 정책(예: 상생형 직장어린이집)이 필요해요."
# - **추가 질문**: "비수도권 거점 도시 육성을 위한 구체적 방안은?"
# - **답변**: "세제 혜택을 지역 기업 유치에 집중하고, 대학-연구소-기업 간 협력 생태계를 구축해야 합니다. 예를 들어 경북 포항에 바이오 클러스터를 확장하면 청년 일자리가 늘어날 거예요."
#
# **3. 제도 운영 개선 필요성**:
# ...
